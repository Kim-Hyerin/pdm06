# %% [markdown]
# <a href="https://colab.research.google.com/github/Kim-Hyerin/pdm06/blob/master/py-tensorflow/tf2_4_mnist_FCN_test_ALL_pdm06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Test of mnist FCN model**
# - FCN2
# - FCN3
# - FCN4
# - FCN5
#
# ***
#
# ![mnist_NN_2_layers](https://raw.githubusercontent.com/Redwoods/Py/master/pdm2020/my-note/py-tensorflow/images/mnist_NN_2_layers.png)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

print(tf.__version__)
# Out:
# 2.3.0

# %% [markdown]
# ## **데이터 로딩, 정규화**

# %%
from keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train, X_test = X_train/255.0, X_test/255.0 # 정규화

print("X_train={0}".format(X_train.shape))
print("y_train={0}".format(y_train.shape)) 
print("X_test={0}".format(X_test.shape))
print("y_test={0}".format(y_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# X_train=(60000, 28, 28)
# y_train=(60000,)
# X_test=(10000, 28, 28)
# y_test=(10000,)

# %%
# One-Hot-Encoding
# Use function to_categorical() to do One-Hot-Encoding
# tf.keras.utils.to_categorical
from keras.utils import to_categorical

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %% [markdown]
# ## **FCN2**

# %%
fcn2 = keras.models.Sequential([ 
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(10, activation='softmax')
])

fcn2.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
fcn2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
fcn2.fit(X_train, y_train, epochs = 20,  batch_size = 32)
# Out:
# Epoch 1/20
#    1/1875 [..............................] - ETA: 0s - loss: 2.5073 - accuracy: 0.0938WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0026s vs `on_train_batch_end` time: 0.0049s). Check your callbacks.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3053 - accuracy: 0.9115
# Epoch 2/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1545 - accuracy: 0.9552
# Epoch 3/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1160 - accuracy: 0.9654
# Epoch 4/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0978 - accuracy: 0.9689
# Epoch 5/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0837 - accuracy: 0.9739
# Epoch 6/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0748 - accuracy: 0.9766
# Epoch 7/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0665 - accuracy: 0.9781
# Epoch 8/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0596 - accuracy: 0.9808
# Epoch 9/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0573 - accuracy: 0.9812
# Epoch 10/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0507 - accuracy: 0.9839
# Epoch 11/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0496 - accuracy: 0.9840
# Epoch 12/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0448 - accuracy: 0.9850
# Epoch 13/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0436 - accuracy: 0.9852
# Epoch 14/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0415 - accuracy: 0.9861
# Epoch 15/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0378 - accuracy: 0.9872
# Epoch 16/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0392 - accuracy: 0.9869
# Epoch 17/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0371 - accuracy: 0.9875
# Epoch 18/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0336 - accuracy: 0.9888
# Epoch 19/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0335 - accuracy: 0.9885
# Epoch 20/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0317 - accuracy: 0.9892

# %%
fcn2.evaluate(X_test, y_test, batch_size =32)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0749 - accuracy: 0.9810
# [0.07491280883550644, 0.9810000061988831]

# %% [markdown]
# ## **FCN3**

# %%
fcn3 = tf.keras.models.Sequential([ 
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(256, activation='relu'),  
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(128, activation='relu'),  
    tf.keras.layers.Dropout(0.25), 
    tf.keras.layers.Dense(10, activation='softmax')
])

fcn3.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
fcn3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               200960
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
fcn3.fit(X_train,y_train, epochs= 20 , batch_size =32)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2782 - accuracy: 0.9165
# Epoch 2/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1338 - accuracy: 0.9592
# Epoch 3/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1031 - accuracy: 0.9688
# Epoch 4/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0897 - accuracy: 0.9726
# Epoch 5/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0759 - accuracy: 0.9764
# Epoch 6/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0679 - accuracy: 0.9781
# Epoch 7/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0638 - accuracy: 0.9801
# Epoch 8/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0577 - accuracy: 0.9818
# Epoch 9/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0528 - accuracy: 0.9833
# Epoch 10/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0485 - accuracy: 0.9845
# Epoch 11/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0480 - accuracy: 0.9846
# Epoch 12/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0458 - accuracy: 0.9855
# Epoch 13/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0443 - accuracy: 0.9861
# Epoch 14/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0443 - accuracy: 0.9863
# Epoch 15/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0396 - accuracy: 0.9875
# Epoch 16/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0382 - accuracy: 0.9878
# Epoch 17/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0347 - accuracy: 0.9891
# Epoch 18/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0377 - accuracy: 0.9884
# Epoch 19/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0363 - accuracy: 0.9886
# Epoch 20/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0345 - accuracy: 0.9895

# %%
fcn3.evaluate(X_test, y_test, batch_size= 32)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0790 - accuracy: 0.9812
# [0.07898609340190887, 0.9811999797821045]

# %% [markdown]
# ## **FCN4**

# %%
fcn4 = tf.keras.models.Sequential([ 
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(256, activation='relu'),  
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(128, activation='relu'),  
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(64, activation='relu'),  
    tf.keras.layers.Dropout(0.25), 
    tf.keras.layers.Dense(10, activation='softmax')
])

fcn4.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
fcn4.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               200960
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                650
# =================================================================
# Total params: 242,762
# Trainable params: 242,762
# Non-trainable params: 0
# _________________________________________________________________

# %%
fcn4.fit(X_train, y_train, epochs = 20 , batch_size =32)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3447 - accuracy: 0.8965
# Epoch 2/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1614 - accuracy: 0.9543
# Epoch 3/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1272 - accuracy: 0.9641
# Epoch 4/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1074 - accuracy: 0.9685
# Epoch 5/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0934 - accuracy: 0.9729
# Epoch 6/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0847 - accuracy: 0.9751
# Epoch 7/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0790 - accuracy: 0.9767
# Epoch 8/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0702 - accuracy: 0.9793
# Epoch 9/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0650 - accuracy: 0.9808
# Epoch 10/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0616 - accuracy: 0.9822
# Epoch 11/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0601 - accuracy: 0.9831
# Epoch 12/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0551 - accuracy: 0.9836
# Epoch 13/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0498 - accuracy: 0.9850
# Epoch 14/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0500 - accuracy: 0.9854
# Epoch 15/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0471 - accuracy: 0.9861
# Epoch 16/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0450 - accuracy: 0.9862
# Epoch 17/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0451 - accuracy: 0.9867
# Epoch 18/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0457 - accuracy: 0.9869
# Epoch 19/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0434 - accuracy: 0.9875
# Epoch 20/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0382 - accuracy: 0.9885

# %%
fcn4.evaluate(X_test, y_test, batch_size =32)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0887 - accuracy: 0.9818
# [0.08874131739139557, 0.9818000197410583]

# %% [markdown]
# ## **FCN5**

# %%
fcn5 = tf.keras.models.Sequential([ 
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(256, activation='relu'), 
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(128, activation='relu'),  
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(64, activation='relu'),  
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(32, activation='relu'),  
    tf.keras.layers.Dropout(0.25), 
    tf.keras.layers.Dense(10, activation='softmax')
])

fcn5.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
fcn5.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               200960
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                330
# =================================================================
# Total params: 244,522
# Trainable params: 244,522
# Non-trainable params: 0
# _________________________________________________________________

# %%
fcn5.fit(X_train, y_train, epochs=20, batch_size =32)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0518 - accuracy: 0.9868
# Epoch 2/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0493 - accuracy: 0.9870
# Epoch 3/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0476 - accuracy: 0.9880
# Epoch 4/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0485 - accuracy: 0.9876
# Epoch 5/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0493 - accuracy: 0.9876
# Epoch 6/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0428 - accuracy: 0.9887
# Epoch 7/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0432 - accuracy: 0.9889
# Epoch 8/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0433 - accuracy: 0.9892
# Epoch 9/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0437 - accuracy: 0.9890
# Epoch 10/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0409 - accuracy: 0.9892
# Epoch 11/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0375 - accuracy: 0.9899
# Epoch 12/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0373 - accuracy: 0.9904
# Epoch 13/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0379 - accuracy: 0.9905
# Epoch 14/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0389 - accuracy: 0.9903
# Epoch 15/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0353 - accuracy: 0.9904
# Epoch 16/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0367 - accuracy: 0.9908
# Epoch 17/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0358 - accuracy: 0.9908
# Epoch 18/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0340 - accuracy: 0.9913
# Epoch 19/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0333 - accuracy: 0.9916
# Epoch 20/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0326 - accuracy: 0.9913

# %%
fcn5.evaluate(X_test, y_test, batch_size = 32)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0989 - accuracy: 0.9819
# [0.09885973483324051, 0.9818999767303467]

# %% [markdown]
# # **[DIY] Hidden layer에 따른 정확도**

# %%
fcn_result = [[0.07491280883550644, 0.9810000061988831], # FCN2
 [0.07898609340190887, 0.9811999797821045], # FCN3
 [0.08874131739139557, 0.9818000197410583], # FCN4
 [0.09885973483324051, 0.9818999767303467]] # FCN5

# %%
# select accuracies FCN2,3,4,5
accuracy = [row[1] for row in fcn_result]
accuracy
# Out:
# [0.9810000061988831,
#  0.9811999797821045,
#  0.9818000197410583,
#  0.9818999767303467]

# %%
x = np.arange(4)
fcns = ['FCN2','FCN3','FCN4','FCN5']
accuracies = [acc*100 for acc in accuracy] # %

plt.bar(x, accuracies)
plt.xticks(x, fcns)
plt.ylim((90,100)) # % , tuple
plt.show()

# %% [markdown]
# ## 모형의 저장
#
# - 트레이닝이 끝난 모형은 save 메서드로 가중치와 함께 hdf5 형식으로 저장
# - load 명령으로 불러 사용

# %%
fcn3.save('fcn3_best.hdf5')

# %%
from keras.models import load_model

model2 = load_model('fcn3_best.hdf5')
model2.evaluate(X_test, y_test, batch_size=32)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0790 - accuracy: 0.9812
# [0.07898609340190887, 0.9811999797821045]

# %% [markdown]
# FCN을 streamlit으로 시뮬레이션하는 웹 앱
# http://life21c.inje.ac.kr:7777
